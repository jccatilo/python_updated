# %%
import yfinance as yf
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
import yfinance as yf
data = yf.download("btc-usd", start="2017-01-02", end="2022-07-01")
data.to_csv('dataset-BTCUSD.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# type(data)
data['date'] = pd.date_range(start='2017-01-01', periods=len(data), freq='D')
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-01-01    963.658020   1003.080017    958.698975    998.325012
# 2017-01-02    998.617004   1031.390015    996.702026   1021.750000
# 2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...                  ...           ...           ...           ...
# 2022-06-26  21496.494141  21783.724609  21016.269531  21027.294922
# 2022-06-27  21028.238281  21478.089844  20620.199219  20735.478516
# 2022-06-28  20731.544922  21164.423828  20228.812500  20280.634766
# 2022-06-29  20281.169922  20364.156250  19937.791016  20104.023438
# 2022-06-30  20108.312500  20141.160156  18729.656250  19784.726562
#
#                Adj Close       Volume       date
# Date
# 2017-01-01    998.325012    147775008 2017-01-01
# 2017-01-02   1021.750000    222184992 2017-01-02
# ...

# %%
# data.plot(kind='line',x='date',y='Close',color='red')
# data.plot(kind='line',x='date',y='Open',color='blue')
# data.plot(kind='line',x='date',y='Volume',color='blue')
import matplotlib.pyplot as plt
plt.plot(data['date'],data['Close'],label='closing price')
plt.plot(data['date'],data['Open'],label='Open price')


plt.legend()
plt.show()
# plt.plot(data['Open'],color='blue')
# plt.show()
# data_close_date = data[['date', 'Close']]
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-01-01    963.658020   1003.080017    958.698975    998.325012
# 2017-01-02    998.617004   1031.390015    996.702026   1021.750000
# 2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...                  ...           ...           ...           ...
# 2022-06-26  21496.494141  21783.724609  21016.269531  21027.294922
# 2022-06-27  21028.238281  21478.089844  20620.199219  20735.478516
# 2022-06-28  20731.544922  21164.423828  20228.812500  20280.634766
# 2022-06-29  20281.169922  20364.156250  19937.791016  20104.023438
# 2022-06-30  20108.312500  20141.160156  18729.656250  19784.726562
#
#                Adj Close       Volume       date
# Date
# 2017-01-01    998.325012    147775008 2017-01-01
# 2017-01-02   1021.750000    222184992 2017-01-02
# ...

# %%
data['change'] = ((data['Open']-data['Close'])/data['Open'])*100

# print(data)
# print(data['change'].max())
# print(data['change'].min())

ax = plt.gca()
data.plot(kind='line',x='date',y='High',figsize=(20, 20),ax=ax, grid = True)
data.plot(kind='line',x='date',y='Low', color='red',figsize=(20,20), ax=ax, grid = True)


data.plot(kind='line',x='date',y='volume', color='red',figsize=(20,20))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'volume'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 8>()
#       5 import matplotlib.pyplot as plt
#       6 from matplotlib.pyplot import figure
# ----> 8 seasonal_decomp = seasonal_decompose(data_close_date['Close'], model="additive")
#       9 figure(figsize=(8, 6), dpi=80)
#      10 seasonal_decomp.plot()
#
# NameError: name 'data_close_date' is not defined
